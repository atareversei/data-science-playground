# %% [markdown]
# # **PROJECT**
# - Explore the financial data
# - Develop a financial dashboard with `dash` library
# - Try using different visualizations

# %%
import yfinance as yf

# %%
apple = yf.Ticker('AAPL')
apple.history(period='5y')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-10-19 00:00:00-04:00  116.687216  117.134665  112.504534  112.815804
# 2020-10-20 00:00:00-04:00  113.029804  115.733966  112.475355  114.304070
# 2020-10-21 00:00:00-04:00  113.487001  115.471347  113.273002  113.681549
# 2020-10-22 00:00:00-04:00  114.245712  114.819619  111.463738  112.592094
# 2020-10-23 00:00:00-04:00  113.214619  113.370257  111.162184  111.901451
# ...                               ...         ...         ...         ...
# 2025-10-13 00:00:00-04:00  249.380005  249.690002  245.559998  247.660004
# 2025-10-14 00:00:00-04:00  246.600006  248.850006  244.699997  247.770004
# 2025-10-15 00:00:00-04:00  249.490005  251.820007  247.470001  249.339996
# 2025-10-16 00:00:00-04:00  248.250000  249.039993  245.130005  247.449997
# 2025-10-17 00:00:00-04:00  248.020004  251.360001  247.270004  250.898193
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
income_statement = apple.financials
balance_sheet = apple.balance_sheet
cash_flow = apple.cash_flow
dividends = apple.dividends
income_statement
# Out:
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# Normalized EBITDA                                   1.346610e+11
# Net Income From Continuing Operation Net Minori...  9.373600e+10
# Reconciled Depreciation                             1.144500e+10
# Reconciled Cost Of Revenue                          2.103520e+11
# EBITDA                                              1.346610e+11
# EBIT                                                1.232160e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   9.373600e+10
# Net Income From Continuing And Discontinued Ope...  9.373600e+10
# ...
